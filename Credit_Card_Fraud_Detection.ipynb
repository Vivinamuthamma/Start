# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivinamuthamma/Start/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pickle

# %% [markdown]
# # Loading the dataset to pandas Dataframe

# %%
credit_card_data = pd.read_csv('/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 267331  162725.0 -0.263226  1.082046 -0.369362 -0.713739  0.460032 -0.685490
# 267332  162726.0  1.934012 -0.214230 -1.727386 -0.129121  1.120018  1.159995
# 267333  162726.0 -0.230649  0.315261 -0.541387 -1.494509  3.321725  3.479110
# 267334  162728.0  1.957555 -0.629307 -0.635363  0.177278 -0.359772  0.307457
# 267335  162728.0  1.972115 -0.161916 -0.962841  0.102880       NaN       NaN
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 267331  0.646106  0.284417 -0.180510  ... -0.254186 -0.681160  0.056685
# 267332 -0.153808  0.306090  0.320286  ...  0.352448  1.231819  0.061903
# 267333  0.470314  0.681980 -0.395329  ... -0.241149 -0.633826 -0.017286
# 267334 -0.744206  0.150395  1.090287  ...  0.163200  0.591334  0.001014
# 267335       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# ...

# %% [markdown]
# Displaying first 5 rows of the dataset

# %% [markdown]
# Dataset information

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267336 entries, 0 to 267335
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    267336 non-null  float64
#  1   V1      267336 non-null  float64
#  2   V2      267336 non-null  float64
#  3   V3      267336 non-null  float64
#  4   V4      267336 non-null  float64
#  5   V5      267335 non-null  float64
#  6   V6      267335 non-null  float64
#  7   V7      267335 non-null  float64
#  8   V8      267335 non-null  float64
#  9   V9      267335 non-null  float64
#  10  V10     267335 non-null  float64
#  11  V11     267335 non-null  float64
#  12  V12     267335 non-null  float64
#  13  V13     267335 non-null  float64
#  14  V14     267335 non-null  float64
#  15  V15     267335 non-null  float64
#  16  V16     267335 non-null  float64
#  17  V17     267335 non-null  float64
#  18  V18     267335 non-null  float64
#  19  V19     267335 non-null  float64
# ...

# %% [markdown]
# #Checking the number of missing values in the dataset

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# since there are some missing values we will handle the missing values

# %% [markdown]
# Checking distribution of legit and fraudulent transactions

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    266855
# 1.0       480
# Name: count, dtype: int64

# %% [markdown]
# 0 --> normal transaction
# 1 --> fraudulent transaction

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %% [markdown]
# seperating the legit and fraudulant transactions

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (266855, 31)
# (480, 31)

# %% [markdown]
# # New Section

# %% [markdown]
# Under sampling to build a sample dataset containing similar distribution of legit and fraudukent transactions
#
# number of fraudulant transactions are 142

# %%
legit_sample = legit.sample = legit.sample(n=142)

# %%
print(legit_sample.shape)
# Out:
# (142, 31)

# %% [markdown]
# Concatentaing the datasets

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 32506    36829.0  1.016233 -1.034907  1.383730  1.072838 -1.663666  0.347023
# 249600  154489.0  2.189191 -0.673278 -1.421533 -1.095467 -0.245381 -0.695507
# 76962    56816.0 -0.234751  0.444214  0.492761  1.350372 -0.317512  0.868822
# 73922    55346.0 -2.165022  1.399798 -1.254162  1.115989 -0.760542 -1.121995
# 78810    57717.0 -2.107986  1.628528 -0.428764 -1.924369 -1.358353 -1.171992
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 32506  -0.929694  0.139169  0.365357  ... -0.577772 -0.939263 -0.030471
# 249600 -0.399127 -0.246410 -0.944722  ...  0.492110  1.409953  0.002608
# 76962  -0.980446 -2.421733 -0.766920  ... -1.039465  0.691969 -0.228383
# 73922   0.074055  1.010374 -0.876768  ...  0.202071  0.688712  0.184993
# 78810  -0.754812  1.498367  0.084160  ...  0.160467 -0.130970  0.155742
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 1.0    480
# 0.0    142
# Name: count, dtype: int64

# %%
legit.Amount.describe()
# Out:
# count    266855.000000
# mean         89.583518
# std         248.365742
# min           0.000000
# 25%           5.990000
# 50%          22.720000
# 75%          79.000000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     480.000000
# mean      121.408896
# std       257.964187
# min         0.000000
# 25%         1.000000
# 50%         8.590000
# 75%       105.080000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    90105.575638 -0.004211 -0.020917  0.060147  0.002265 -0.013083
# 1.0    78578.960417 -4.843074  3.715599 -7.127606  4.610425 -3.247162
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.010805  0.001859 -0.001145  0.004597  ...  0.000991 -0.001380
# 1.0   -1.405621 -5.662963  0.616471 -2.619694  ...  0.371746  0.739635
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.004673 -0.002363  0.001553  0.009725  0.001027 -0.000720  0.000637
# 1.0    0.001402 -0.051203 -0.109934  0.045371  0.047460  0.162716  0.076705
#
#            Amount
# Class
# 0.0     89.583518
# 1.0    121.408896
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting data into features and targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 32506    36829.0  1.016233 -1.034907  1.383730  1.072838 -1.663666  0.347023
# 249600  154489.0  2.189191 -0.673278 -1.421533 -1.095467 -0.245381 -0.695507
# 76962    56816.0 -0.234751  0.444214  0.492761  1.350372 -0.317512  0.868822
# 73922    55346.0 -2.165022  1.399798 -1.254162  1.115989 -0.760542 -1.121995
# 78810    57717.0 -2.107986  1.628528 -0.428764 -1.924369 -1.358353 -1.171992
# ...          ...       ...       ...       ...       ...       ...       ...
# 262826  160665.0 -0.417340  4.700055 -7.521767  7.671884  0.260821 -2.646693
# 263080  160791.0  2.132386  0.705608 -3.530759  0.514779  1.527175 -1.716268
# 263274  160870.0 -0.644278  5.002352 -8.252739  7.756915 -0.216267 -2.751496
# 263324  160895.0 -0.848290  2.719882 -6.199070  3.044437 -3.301910 -1.992117
# 263877  161154.0 -3.387601  3.977881 -6.978585  1.657766 -1.100500 -3.599487
#
# ...

# %%
print(Y)
# Out:
# 32506     0.0
# 249600    0.0
# 76962     0.0
# 73922     0.0
# 78810     0.0
#          ...
# 262826    1.0
# 263080    1.0
# 263274    1.0
# 263324    1.0
# 263877    1.0
# Name: Class, Length: 622, dtype: float64

# %% [markdown]
# Split the data into training data and testing data

# %%
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape, X_test.shape)
# Out:
# (622, 30) (497, 30) (125, 30)

# %% [markdown]
# Scalar the features using standard scaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Model Training using Logistic Regression Model

# %%
model = LogisticRegression()

# %% [markdown]
# training the logistic regression model with trainig dataset

# %%
model.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model evaluation for checking accuracy score

# %%
print('Accuracy on Training the data:',training_data_accuracy)
# Out:
# Accuracy on Training the data: 0.2709677419354839

# %% [markdown]
# Accuracy on test data

# %%
X_test_prediction = model.predict(X_test_scaled)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on test data: ',test_data_accuracy)
# Out:
# Accuracy score on test data:  0.928
